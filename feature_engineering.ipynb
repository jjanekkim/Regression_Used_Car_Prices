# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

import os
import pickle

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv(r"C:\Users\nene0\Desktop\Projects\kaggle_Used_Car_Regression\cleaned_train_2024-09-18_16-29-24.csv")

df.head()
# Out:
#            brand              model  model_year  milage      fuel_type
# 0           MINI      Cooper S Base        2007  213000       Gasoline  \
# 1        Lincoln              LS V8        2002  143250       Gasoline
# 2      Chevrolet  Silverado 2500 LT        2002  136731  E85 Flex Fuel
# 3        Genesis   G90 5.0 Ultimate        2017   19500       Gasoline
# 4  Mercedes-Benz        Metris Base        2021    7388       Gasoline
#
#                                               engine
# 0       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel  \
# 1       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col
# 0                             A/T  Yellow    Gray  \
# 1                             A/T  Silver   Beige
# 2                             A/T    Blue    Gray
# 3  Transmission w/Dual Shift Mode   Black   Black
# 4                     7-Speed A/T   Black   Beige
#
#                                  accident clean_title  price
# 0                           None reported         Yes   4200
# 1  At least 1 accident or damage reported         Yes   4999
# 2                           None reported         Yes  13900
# 3                           None reported         Yes  45000
# 4                           None reported         Yes  97500

# %% [markdown]
# #### Create_dictionary function

# %%
def create_disctionary(data, group, column):
    mode = data.groupby(group)[column].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else None).reset_index()
    my_dict = mode.set_index(group)[column].to_dict()
    return my_dict

# %% [markdown]
# ### Age & Age Bins

# %%
df['age'] = datetime.now().year - df['model_year']
df['age_bins'] = pd.cut(df['age'], bins=[0, 2, 5, 10, 15, 20, df['age'].max()], labels=['Fairly New', '3-5 Years', '6-10 Years', '11-15 Years', '16-20 Years', 'Old'])

# %% [markdown]
# ### Milage per Year

# %%
df.head()
# Out:
#            brand              model  model_year  milage      fuel_type
# 0           MINI      Cooper S Base        2007  213000       Gasoline  \
# 1        Lincoln              LS V8        2002  143250       Gasoline
# 2      Chevrolet  Silverado 2500 LT        2002  136731  E85 Flex Fuel
# 3        Genesis   G90 5.0 Ultimate        2017   19500       Gasoline
# 4  Mercedes-Benz        Metris Base        2021    7388       Gasoline
#
#                                               engine
# 0       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel  \
# 1       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col
# 0                             A/T  Yellow    Gray  \
# 1                             A/T  Silver   Beige
# 2                             A/T    Blue    Gray
# 3  Transmission w/Dual Shift Mode   Black   Black
# 4                     7-Speed A/T   Black   Beige
#
#                                  accident clean_title  price  age     age_bins
# 0                           None reported         Yes   4200   17  16-20 Years
# 1  At least 1 accident or damage reported         Yes   4999   22          Old
# 2                           None reported         Yes  13900   22          Old
# 3                           None reported         Yes  45000    7   6-10 Years
# 4                           None reported         Yes  97500    3    3-5 Years

# %%
df['mi_per_year'] = round(df['milage'] / df['age'], 2)

# %%
df[df['mi_per_year']==np.inf]
# Out:
#            brand                  model  model_year  milage fuel_type
# 5566       Lexus           NX 300h Base        2024   16425    Hybrid  \
# 6139         BMW           330 i xDrive        2024    8700  Gasoline
# 7160         BMW                  M3 CS        2024   31850  Gasoline
# 7223        Ford  Expedition Timberline        2024   23300  Gasoline
# 7409         BMW                  M3 CS        2024   34254  Gasoline
# ...          ...                    ...         ...     ...       ...
# 178315       BMW                  M3 CS        2024    3415  Gasoline
# 180561       BMW                  M3 CS        2024   48200  Gasoline
# 184526       RAM          1500 Big Horn        2024   18385  Gasoline
# 185313  INFINITI              QX56 Base        2024    7100  Gasoline
# 187649       BMW                  M3 CS        2024   13850  Gasoline
#
#                                                    engine
# 5566                         2.5L I4 16V MPFI DOHC Hybrid  \
# 6139         255.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 7160    543.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 7223        440.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 7409    543.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# ...                                                   ...
# 178315  543.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 180561  543.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 184526       395.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 185313       400.0HP 5.6L 8 Cylinder Engine Gasoline Fuel
# 187649  543.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
#
#                           transmission ext_col int_col       accident
# 5566                     Automatic CVT   Black    Gray  None reported  \
# 6139                               A/T    Blue   White  None reported
# 7160    Transmission w/Dual Shift Mode   Black   Black  None reported
# 7223                      10-Speed A/T    Gray   Black  None reported
# 7409    Transmission w/Dual Shift Mode   White   Black  None reported
# ...                                ...     ...     ...            ...
# 178315                             A/T   Black   Black  None reported
# 180561  Transmission w/Dual Shift Mode   Black   Black  None reported
# 184526                     8-Speed A/T   White   Black  None reported
# 185313                     7-Speed A/T   Black   Black  None reported
# 187649  Transmission w/Dual Shift Mode    Gray   Black  None reported
#
#        clean_title   price  age age_bins  mi_per_year
# 5566           Yes   44700    0      NaN          inf
# 6139           Yes   33000    0      NaN          inf
# 7160           Yes   22550    0      NaN          inf
# 7223           Yes   69500    0      NaN          inf
# 7409           Yes   63900    0      NaN          inf
# ...            ...     ...  ...      ...          ...
# 178315         Yes  179900    0      NaN          inf
# 180561         Yes   67000    0      NaN          inf
# 184526         Yes   57000    0      NaN          inf
# 185313         Yes   74900    0      NaN          inf
# 187649         Yes   59900    0      NaN          inf
#
# [162 rows x 15 columns]

# %%
df['mi_per_year'] = np.where(df['mi_per_year']==np.inf, df['milage'], df['mi_per_year'])

# %%
df['mi_per_year'].iloc[5566]
# Out:
# 16425.0

# %% [markdown]
# ### Horsepower & Engine Liter & Cylinder

# %%
def extract_horsepower(hp):
    try:
        pattern = r'\d+\.\d+HP'
        match = re.search(pattern, hp)
        hp_string = match.group()
        horsepower = hp_string.replace('.0HP', '')
        horsepower = int(horsepower)
        return horsepower
    except:
        return np.nan
    
def extract_engine_liter(liter):
    try:
        pattern = r'\d+\.\d+L'
        match = re.search(pattern, liter)
        liter_string = match.group()
        liter = liter_string.replace('L', '')
        liter = float(liter)
        return liter
    except:
        return np.nan
    
def extract_cylinder(cyn):
    try:
        pattern = r'\d+ Cylinder'
        match = re.search(pattern, cyn)
        cyn_string = match.group()
        cylinder = cyn_string.replace(' Cylinder', '')
        cylinder = int(cylinder)
        return cylinder
    except:
        return np.nan

# %%
# Create a 'horsepower', 'engine_liter', 'cylinder' features using the 'engine'.
df['hp'] = df['engine'].apply(extract_horsepower)
df['engine_liter'] = df['engine'].apply(extract_engine_liter)
df['cylinder'] = df['engine'].apply(extract_cylinder)

# %%
hp_median = df['hp'].median()
engine_liter_median = df['engine_liter'].median()
cylinder_median = df['cylinder'].median()

# Function to fill missing values with medians
def fill_missing_values(row):
    row['hp'] = row['hp'] if not pd.isna(row['hp']) else hp_median
    row['engine_liter'] = row['engine_liter'] if not pd.isna(row['engine_liter']) else engine_liter_median
    row['cylinder'] = row['cylinder'] if not pd.isna(row['cylinder']) else cylinder_median
    return row

# %%
df = df.apply(fill_missing_values, axis=1)

# %% [markdown]
# #### Correcting Horsepower

# %%
df[df['hp'] == 1020]
# Out:
#         brand              model  model_year  milage fuel_type
# 3244    Tesla      Model S Plaid        2021   18000  Electric  \
# 13551   Tesla      Model X Plaid        2023     200  Electric
# 18664   Tesla      Model X Plaid        2022   26500  Electric
# 24009   Tesla      Model X Plaid        2021   44000  Electric
# 36210   Tesla      Model S Plaid        2021  105000  Electric
# 37420   Tesla      Model S Plaid        2022    4820  Electric
# 39613   Tesla      Model X Plaid        2022   20000  Electric
# 46303   Tesla      Model X Plaid        2022   15000  Electric
# 51400   Tesla      Model X Plaid        2023   20100  Electric
# 51728   Tesla      Model X Plaid        2021   20000  Electric
# 51799   Tesla      Model X Plaid        2021   20100  Electric
# 59745   Tesla      Model S Plaid        2023   20100  Electric
# 62129   Tesla      Model S Plaid        2021   20100  Electric
# 67072   Tesla      Model X Plaid        2023    6188  Electric
# 75706   Tesla      Model X Plaid        2017   10431  Electric
# 82823   Tesla      Model X Plaid        2019   67500  Electric
# 89496   Tesla      Model S Plaid        2020   51830  Electric
# 97890   Tesla      Model S Plaid        2018   20100  Electric
# 111449  Tesla      Model X Plaid        2023    4000  Electric
# 112946  Tesla      Model S Plaid        2022    6188  Electric
# 113797  Tesla      Model X Plaid        2022   24500  Electric
# 113920  Tesla      Model S Plaid        2022   20100  Electric
# 117183  Tesla      Model S Plaid        2022   20100  Electric
# 120744  Tesla      Model X Plaid        2022   20100  Electric
# 123295  Tesla      Model X Plaid        2023   20100  Electric
# 125541  Tesla      Model S Plaid        2021   20100  Electric
# 125544  Tesla      Model X Plaid        2022   11400  Electric
# 132477  Tesla      Model X Plaid        2021   27123  Electric
# 141010  Tesla      Model X Plaid        2022   14000  Electric
# 154623  Tesla      Model S Plaid        2021   19000  Electric
# 166972  Tesla      Model S Plaid        2021   20100  Electric
# 167255  Tesla      Model S Plaid        2021   20100  Electric
# 167275  Tesla      Model X Plaid        2022   15000  Electric
# 169562  Tesla      Model X Plaid        2022   13800  Electric
# 172376  Tesla      Model X Plaid        2022   20000  Electric
# 174099  Tesla      Model S Plaid        2021   20100  Electric
# 174875  Tesla      Model S Plaid        2023   20104  Electric
# 187842   Ford  Mustang Mach-E GT        2023    6188  Electric
#
#                                               engine transmission ext_col
# 3244    1020.0HP Electric Motor Electric Fuel System          A/T     Red  \
# 13551   1020.0HP Electric Motor Electric Fuel System          A/T   Black
# 18664   1020.0HP Electric Motor Electric Fuel System  1-Speed A/T    Blue
# 24009   1020.0HP Electric Motor Electric Fuel System          A/T     Red
# 36210   1020.0HP Electric Motor Electric Fuel System          A/T     Red
# 37420   1020.0HP Electric Motor Electric Fuel System          A/T   White
# 39613   1020.0HP Electric Motor Electric Fuel System          A/T   White
# 46303   1020.0HP Electric Motor Electric Fuel System          A/T    Blue
# 51400   1020.0HP Electric Motor Electric Fuel System          A/T     Red
# 51728   1020.0HP Electric Motor Electric Fuel System          A/T   White
# 51799   1020.0HP Electric Motor Electric Fuel System  1-Speed A/T    Gray
# 59745   1020.0HP Electric Motor Electric Fuel System          A/T   White
# 62129   1020.0HP Electric Motor Electric Fuel System          A/T   Black
# 67072   1020.0HP Electric Motor Electric Fuel System  1-Speed A/T   White
# 75706   1020.0HP Electric Motor Electric Fuel System          A/T   Black
# 82823   1020.0HP Electric Motor Electric Fuel System          A/T  Silver
# 89496   1020.0HP Electric Motor Electric Fuel System          A/T   Black
# 97890   1020.0HP Electric Motor Electric Fuel System          A/T   Black
# 111449  1020.0HP Electric Motor Electric Fuel System          A/T    Blue
# 112946  1020.0HP Electric Motor Electric Fuel System          A/T     Red
# 113797  1020.0HP Electric Motor Electric Fuel System          A/T   Brown
# 113920  1020.0HP Electric Motor Electric Fuel System          A/T    Gray
# 117183  1020.0HP Electric Motor Electric Fuel System          A/T     Red
# 120744  1020.0HP Electric Motor Electric Fuel System          A/T   Black
# 123295  1020.0HP Electric Motor Electric Fuel System          A/T   White
# 125541  1020.0HP Electric Motor Electric Fuel System          A/T  Purple
# 125544  1020.0HP Electric Motor Electric Fuel System          A/T   White
# 132477  1020.0HP Electric Motor Electric Fuel System          A/T   Green
# 141010  1020.0HP Electric Motor Electric Fuel System          A/T   White
# 154623  1020.0HP Electric Motor Electric Fuel System          A/T   White
# 166972  1020.0HP Electric Motor Electric Fuel System          A/T     Red
# 167255  1020.0HP Electric Motor Electric Fuel System          A/T   Black
# 167275  1020.0HP Electric Motor Electric Fuel System          A/T     Red
# 169562  1020.0HP Electric Motor Electric Fuel System          A/T   White
# 172376  1020.0HP Electric Motor Electric Fuel System  1-Speed A/T  Silver
# 174099  1020.0HP Electric Motor Electric Fuel System  1-Speed A/T     Red
# 174875  1020.0HP Electric Motor Electric Fuel System    Automatic   Black
# 187842  1020.0HP Electric Motor Electric Fuel System          A/T    Gray
#
#        int_col                                accident clean_title   price
# 3244     Black                           None reported         Yes   55000  \
# 13551    Black                           None reported         Yes   85000
# 18664    Black                           None reported         Yes   49900
# 24009    Black                           None reported         Yes   54000
# 36210    Black  At least 1 accident or damage reported         Yes   20500
# 37420    White                           None reported         Yes  110000
# 39613    White                           None reported         Yes  115000
# 46303    Black  At least 1 accident or damage reported         Yes   54900
# 51400    White                           None reported         Yes   49700
# 51728    White                           None reported         Yes   56900
# 51799    White                           None reported         Yes   95999
# 59745    White                           None reported         Yes   62999
# 62129    Black                           None reported         Yes   56515
# 67072    White                           None reported         Yes  105000
# 75706    White                           None reported         Yes   16500
# 82823    Black  At least 1 accident or damage reported         Yes   49900
# 89496    Black                           None reported         Yes   69500
# 97890    Black                           None reported         Yes   73600
# 111449   Black                           None reported         Yes   44900
# 112946   White                           None reported         Yes   92500
# 113797   White                           None reported         Yes   57850
# 113920   Black                           None reported         Yes   69995
# 117183   Black                           None reported         Yes   26000
# 120744   White  At least 1 accident or damage reported         Yes   69950
# 123295   White                           None reported         Yes   68750
# 125541   White                           None reported         Yes   51000
# 125544   White                           None reported         Yes   64000
# 132477   White                           None reported         Yes   89000
# 141010   Black                           None reported         Yes   41900
# 154623   Black                           None reported         Yes   70999
# 166972   White                           None reported         Yes   52000
# 167255     Red                           None reported         Yes   92500
# 167275   Black                           None reported         Yes  119999
# 169562   Black                           None reported         Yes   51999
# 172376   White                           None reported         Yes   63000
# 174099   Black                           None reported         Yes   59000
# 174875   Black                           None reported     Unknown   68990
# 187842    Gray                           None reported         Yes   95999
#
#         age    age_bins  mi_per_year      hp  engine_liter  cylinder
# 3244      3   3-5 Years      6000.00  1020.0           3.5       6.0
# 13551     1  Fairly New       200.00  1020.0           3.5       6.0
# 18664     2  Fairly New     13250.00  1020.0           3.5       6.0
# 24009     3   3-5 Years     14666.67  1020.0           3.5       6.0
# 36210     3   3-5 Years     35000.00  1020.0           3.5       6.0
# 37420     2  Fairly New      2410.00  1020.0           3.5       6.0
# 39613     2  Fairly New     10000.00  1020.0           3.5       6.0
# 46303     2  Fairly New      7500.00  1020.0           3.5       6.0
# 51400     1  Fairly New     20100.00  1020.0           3.5       6.0
# 51728     3   3-5 Years      6666.67  1020.0           3.5       6.0
# 51799     3   3-5 Years      6700.00  1020.0           3.5       6.0
# 59745     1  Fairly New     20100.00  1020.0           3.5       6.0
# 62129     3   3-5 Years      6700.00  1020.0           3.5       6.0
# 67072     1  Fairly New      6188.00  1020.0           3.5       6.0
# 75706     7  6-10 Years      1490.14  1020.0           3.5       6.0
# 82823     5   3-5 Years     13500.00  1020.0           3.5       6.0
# 89496     4   3-5 Years     12957.50  1020.0           3.5       6.0
# 97890     6  6-10 Years      3350.00  1020.0           3.5       6.0
# 111449    1  Fairly New      4000.00  1020.0           3.5       6.0
# 112946    2  Fairly New      3094.00  1020.0           3.5       6.0
# 113797    2  Fairly New     12250.00  1020.0           3.5       6.0
# 113920    2  Fairly New     10050.00  1020.0           3.5       6.0
# 117183    2  Fairly New     10050.00  1020.0           3.5       6.0
# 120744    2  Fairly New     10050.00  1020.0           3.5       6.0
# 123295    1  Fairly New     20100.00  1020.0           3.5       6.0
# 125541    3   3-5 Years      6700.00  1020.0           3.5       6.0
# 125544    2  Fairly New      5700.00  1020.0           3.5       6.0
# 132477    3   3-5 Years      9041.00  1020.0           3.5       6.0
# 141010    2  Fairly New      7000.00  1020.0           3.5       6.0
# 154623    3   3-5 Years      6333.33  1020.0           3.5       6.0
# 166972    3   3-5 Years      6700.00  1020.0           3.5       6.0
# 167255    3   3-5 Years      6700.00  1020.0           3.5       6.0
# 167275    2  Fairly New      7500.00  1020.0           3.5       6.0
# 169562    2  Fairly New      6900.00  1020.0           3.5       6.0
# 172376    2  Fairly New     10000.00  1020.0           3.5       6.0
# 174099    3   3-5 Years      6700.00  1020.0           3.5       6.0
# 174875    1  Fairly New     20104.00  1020.0           3.5       6.0
# 187842    1  Fairly New      6188.00  1020.0           3.5       6.0

# %%
hp_dict = create_disctionary(df, 'model', 'hp')
pickle.dump(hp_dict, open("hp_dict.pickle", "wb"))

# %%
hp_dict.get('Mustang Mach-E GT')
# Out:
# 480.0

# %%
df['hp'] = df.apply(lambda row: hp_dict[row['model']] if row['model'] in hp_dict and row['hp'] != hp_dict[row['model']] else row['hp'], axis=1)

# %%
df[df['hp'] == 1020]['brand'].unique()
# Out:
# array(['Tesla'], dtype=object)

# %% [markdown]
# ### Horsepower per Liter

# %%
# Horsepower per liter: a measure of an engine's efficiency

df['engine_efficiency'] = round(df['hp'] / df['engine_liter'], 2)

# %%
df.head()
# Out:
#            brand              model  model_year  milage      fuel_type
# 0           MINI      Cooper S Base        2007  213000       Gasoline  \
# 1        Lincoln              LS V8        2002  143250       Gasoline
# 2      Chevrolet  Silverado 2500 LT        2002  136731  E85 Flex Fuel
# 3        Genesis   G90 5.0 Ultimate        2017   19500       Gasoline
# 4  Mercedes-Benz        Metris Base        2021    7388       Gasoline
#
#                                               engine
# 0       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel  \
# 1       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col
# 0                             A/T  Yellow    Gray  \
# 1                             A/T  Silver   Beige
# 2                             A/T    Blue    Gray
# 3  Transmission w/Dual Shift Mode   Black   Black
# 4                     7-Speed A/T   Black   Beige
#
#                                  accident clean_title  price  age
# 0                           None reported         Yes   4200   17  \
# 1  At least 1 accident or damage reported         Yes   4999   22
# 2                           None reported         Yes  13900   22
# 3                           None reported         Yes  45000    7
# 4                           None reported         Yes  97500    3
#
#       age_bins  mi_per_year     hp  engine_liter  cylinder  engine_efficiency
# 0  16-20 Years     12529.41  172.0           1.6       4.0             107.50
# 1          Old      6511.36  252.0           3.9       8.0              64.62
# 2          Old      6215.05  360.0           5.3       8.0              67.92
# 3   6-10 Years      2785.71  420.0           5.0       8.0              84.00
# 4    3-5 Years      2462.67  208.0           2.0       4.0             104.00

# %% [markdown]
# ### Brand Popularity

# %%
brand_counts = df['brand'].value_counts()
df['brand_count'] = df['brand'].map(brand_counts)
df['brand_rank'] = df['brand_count'].rank(method='dense', ascending=False)

# %%
pickle.dump(brand_counts, open("brand_counts.pickle", "wb"))

# %% [markdown]
# ### Transmission & Num Gear

# %%
def extract_gear(gear):
    try:
        pattern = r'^\d+'
        match = re.search(pattern, gear)
        num_gear = match.group()
        return num_gear
    except:
        return np.nan

# %%
df['num_gear'] = df['transmission'].apply(extract_gear)

# %%
df[df['transmission']=='Single-Speed Fixed Gear']
# Out:
#           brand              model  model_year  milage fuel_type
# 4516    Bentley     Bentayga Speed        2020   22001  Gasoline  \
# 29492   Porsche             Taycan        2020    2076  Electric
# 37890   Porsche       Taycan Turbo        2022    3158  Electric
# 39075   Porsche       Taycan Turbo        2020    2076  Electric
# 40380   Porsche          Taycan 4S        2023   11089  Gasoline
# 66152   Porsche       Taycan Turbo        2021   11078  Electric
# 87772   Porsche        Taycan Base        2020    2116  Electric
# 96793   Porsche       Taycan Turbo        2020   21028  Electric
# 102902  Porsche       Taycan Turbo        2022    3574  Electric
# 108484  Porsche       Taycan Turbo        2022    2076  Electric
# 113104  Porsche       Taycan Turbo        2020   21028  Electric
# 140221  Porsche       Taycan Turbo        2021   12209  Gasoline
# 162383  Porsche       Taycan Turbo        2020    2076  Electric
# 162733      BMW            M5 Base        2016     816  Gasoline
# 165109    Lucid  Air Grand Touring        2020   25462  Electric
# 171165  Porsche       Taycan Turbo        2020    1885  Electric
#
#                                   engine             transmission
# 4516    6.0L W12 48V PDI DOHC Twin Turbo  Single-Speed Fixed Gear  \
# 29492                           Electric  Single-Speed Fixed Gear
# 37890            Dual AC Electric Motors  Single-Speed Fixed Gear
# 39075            Dual AC Electric Motors  Single-Speed Fixed Gear
# 40380            Dual AC Electric Motors  Single-Speed Fixed Gear
# 66152            Dual AC Electric Motors  Single-Speed Fixed Gear
# 87772            Dual AC Electric Motors  Single-Speed Fixed Gear
# 96793            Dual AC Electric Motors  Single-Speed Fixed Gear
# 102902           Dual AC Electric Motors  Single-Speed Fixed Gear
# 108484           Dual AC Electric Motors  Single-Speed Fixed Gear
# 113104           Dual AC Electric Motors  Single-Speed Fixed Gear
# 140221           Dual AC Electric Motors  Single-Speed Fixed Gear
# 162383                          Electric  Single-Speed Fixed Gear
# 162733           Dual AC Electric Motors  Single-Speed Fixed Gear
# 165109           Dual AC Electric Motors  Single-Speed Fixed Gear
# 171165           Dual AC Electric Motors  Single-Speed Fixed Gear
#
#                       ext_col     int_col       accident  ... age    age_bins
# 4516             Beluga Black     Hotspur  None reported  ...   4   3-5 Years  \
# 29492                    Gray       Beige  None reported  ...   4   3-5 Years
# 37890                    Gray       Black  None reported  ...   2  Fairly New
# 39075                    Gray     Unknown  None reported  ...   4   3-5 Years
# 40380                   Black       Black  None reported  ...   1  Fairly New
# 66152                   Black       Beige  None reported  ...   3   3-5 Years
# 87772                  Silver       Black  None reported  ...   4   3-5 Years
# 96793                   Black       Beige  None reported  ...   4   3-5 Years
# 102902  Gentian Blue Metallic       Black  None reported  ...   2  Fairly New
# 108484                  Black       Black  None reported  ...   2  Fairly New
# 113104                  Black       Black  None reported  ...   4   3-5 Years
# 140221          Phantom Black       Black  None reported  ...   3   3-5 Years
# 162383                   Gray       Black  None reported  ...   4   3-5 Years
# 162733           Alpine White  Anthracite  None reported  ...   8  6-10 Years
# 165109                  Black       Black  None reported  ...   4   3-5 Years
# 171165                  Black       Black  None reported  ...   4   3-5 Years
#
#         mi_per_year     hp  engine_liter  cylinder  engine_efficiency
# 4516        5500.25  328.0           6.0       6.0              54.67  \
# 29492        519.00  328.0           3.5       6.0              93.71
# 37890       1579.00  328.0           3.5       6.0              93.71
# 39075        519.00  328.0           3.5       6.0              93.71
# 40380      11089.00  328.0           3.5       6.0              93.71
# 66152       3692.67  328.0           3.5       6.0              93.71
# 87772        529.00  375.0           3.5       6.0             107.14
# 96793       5257.00  328.0           3.5       6.0              93.71
# 102902      1787.00  328.0           3.5       6.0              93.71
# 108484      1038.00  328.0           3.5       6.0              93.71
# 113104      5257.00  328.0           3.5       6.0              93.71
# 140221      4069.67  328.0           3.5       6.0              93.71
# 162383       519.00  328.0           3.5       6.0              93.71
# 162733       102.00  600.0           3.5       6.0             171.43
# 165109      6365.50  536.0           3.5       6.0             153.14
# 171165       471.25  328.0           3.5       6.0              93.71
#
#         brand_count  brand_rank  num_gear
# 4516           1157        27.0       NaN
# 29492         10554         6.0       NaN
# 37890         10554         6.0       NaN
# 39075         10554         6.0       NaN
# 40380         10554         6.0       NaN
# 66152         10554         6.0       NaN
# 87772         10554         6.0       NaN
# 96793         10554         6.0       NaN
# 102902        10554         6.0       NaN
# 108484        10554         6.0       NaN
# 113104        10554         6.0       NaN
# 140221        10554         6.0       NaN
# 162383        10554         6.0       NaN
# 162733        17021         3.0       NaN
# 165109           71        45.0       NaN
# 171165        10554         6.0       NaN
#
# [16 rows x 22 columns]

# %%
df.loc[((df['transmission']=='Single-Speed Fixed Gear')&(df['num_gear'].isna())), 'num_gear'] = 1

# %%
def remove_speed(trans):
    pattern = r'\d+-[Ss][Pp][Ee][Ee][Dd]\s*'
    return re.sub(pattern, '', trans).strip()

df['transmission'] = df['transmission'].apply(remove_speed)

# %%
df[df['transmission']=='SCHEDULED FOR OR IN PRODUCTION']
# Out:
#        brand                 model  model_year  milage fuel_type
# 15127    BMW         M440 i xDrive        2021   61145    Hybrid  \
# 24462   Audi  Q5 2.0T Premium Plus        2019   36486  Gasoline
# 74912    BMW                M240 i        2021   13177  Gasoline
# 76121    BMW                 M3 CS        2022   26609  Gasoline
# 115203   BMW          X6 xDrive40i        2020   28567  Gasoline
# 136712   BMW          530 i xDrive        2019   48156    Hybrid
#
#                                               engine
# 15127                                3.0 Liter Turbo  \
# 24462   252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 74912                                3.0 Liter Turbo
# 76121                                3.0 Liter Turbo
# 115203                               3.0 Liter Turbo
# 136712                               3.0 Liter Turbo
#
#                           transmission                    ext_col
# 15127   SCHEDULED FOR OR IN PRODUCTION               Alpine White  \
# 24462   SCHEDULED FOR OR IN PRODUCTION                       Gray
# 74912   SCHEDULED FOR OR IN PRODUCTION  Brilliant Silver Metallic
# 76121   SCHEDULED FOR OR IN PRODUCTION      Mythos Black Metallic
# 115203  SCHEDULED FOR OR IN PRODUCTION      Carbon Black Metallic
# 136712  SCHEDULED FOR OR IN PRODUCTION    Glacier Silver Metallic
#
#                      int_col                                accident  ... age
# 15127                  Black                           None reported  ...   3  \
# 24462                    Red                           None reported  ...   5
# 74912                  Black                           None reported  ...   3
# 76121                  White                           None reported  ...   2
# 115203                 Black  At least 1 accident or damage reported  ...   4
# 136712  Canberra Beige/Black                           None reported  ...   5
#
#           age_bins  mi_per_year     hp  engine_liter  cylinder
# 15127    3-5 Years     20381.67  382.0           3.5       6.0  \
# 24462    3-5 Years      7297.20  220.0           2.0       4.0
# 74912    3-5 Years      4392.33  335.0           3.5       6.0
# 76121   Fairly New     13304.50  453.0           3.5       6.0
# 115203   3-5 Years      7141.75  335.0           3.5       6.0
# 136712   3-5 Years      9631.20  328.0           3.5       6.0
#
#         engine_efficiency  brand_count  brand_rank  num_gear
# 15127              109.14        17021         3.0       NaN
# 24462              110.00        10898         5.0       NaN
# 74912               95.71        17021         3.0       NaN
# 76121              129.43        17021         3.0       NaN
# 115203              95.71        17021         3.0       NaN
# 136712              93.71        17021         3.0       NaN
#
# [6 rows x 22 columns]

# %%
# Function to replace 'A/T' with 'Automatic' and 'M/T' with 'Manual'
def replace_transmission(trans):
    if 'A/T' in trans:
        return trans.replace('A/T', 'Automatic')
    elif 'M/T' in trans:
        return trans.replace('M/T', 'Manual')
    elif 'Variable' in trans:
        return trans.replace('Variable', 'CVT')
    else:
        return trans

# Apply the function to the 'transmission' column
df['transmission'] = df['transmission'].apply(replace_transmission)

# %%
correct_transmission = {
    'CVT Transmission': 'CVT',
    'Automatic CVT': 'CVT',
    'Electronically Controlled Automatic with O':'Automatic with Overdrive',
    'F': np.nan,
    'CVT-F':'CVT',
    '2': np.nan,
    '6 Speed At/Mt': 'Automated Manual',
    '': np.nan,
    'AT':'Automatic',
    'SCHEDULED FOR OR IN PRODUCTION': np.nan,
    '6 Speed Mt': 'Manual'}

# %%
df['transmission'] = df['transmission'].replace(correct_transmission)

# %%
df['transmission'].fillna(df['transmission'].mode()[0], inplace=True)
df['num_gear'].fillna(df['num_gear'].mode()[0], inplace=True)

# %% [markdown]
# ### Drop features

# %%
df.drop(columns=['model_year', 'engine', 'brand_count'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188373 entries, 0 to 188372
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   brand              188373 non-null  object
#  1   model              188373 non-null  object
#  2   milage             188373 non-null  int64
#  3   fuel_type          188373 non-null  object
#  4   transmission       188373 non-null  object
#  5   ext_col            188373 non-null  object
#  6   int_col            188373 non-null  object
#  7   accident           188373 non-null  object
#  8   clean_title        188373 non-null  object
#  9   price              188373 non-null  int64
#  10  age                188373 non-null  int64
#  11  age_bins           188211 non-null  object
#  12  mi_per_year        188373 non-null  float64
#  13  hp                 188373 non-null  float64
#  14  engine_liter       188373 non-null  float64
#  15  cylinder           188373 non-null  float64
#  16  engine_efficiency  188373 non-null  float64
#  17  brand_rank         188373 non-null  float64
#  18  num_gear           188373 non-null  object
# dtypes: float64(6), int64(3), object(10)
# memory usage: 27.3+ MB

# %%
timestamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
folder_path = r'C:\Users\nene0\Desktop\Projects\kaggle_Used_Car_Regression'
file_path = os.path.join(folder_path, f'featured_train_{timestamp}.csv')
df.to_csv(file_path, index=False)
